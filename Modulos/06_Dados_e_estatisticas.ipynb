# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
filmes.head(2)
# Out:
#    filmeId            titulo                                      generos
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
notas_do_toy_story = notas.query("filmeId==1")
notas_do_jumanji = notas.query("filmeId==2")
print(len(notas_do_toy_story), len(notas_do_jumanji))
# Out:
# 215 110

# %%
print("Nota média do Toy Story %.2f" % notas_do_toy_story.nota.mean())
print("Nota média do Jumanji %.2f" % notas_do_jumanji.nota.mean())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43

# %%
print(notas_do_toy_story.nota.std(), notas_do_jumanji.nota.std())
# Out:
# 0.8348591407114047 0.8817134921476455

# %%
print("Nota mediana do Toy Story %.2f" % notas_do_toy_story.nota.median())
print("Nota mediana do Jumanji %.2f" % notas_do_jumanji.nota.median())
# Out:
# Nota mediana do Toy Story 4.00
# Nota mediana do Jumanji 3.50

# %%
import numpy as np

filme1 = np.append( np.array([2.5] * 10), np.array([3.5] * 10))
filme2 = np.append( np.array([5] * 10), np.array([1] * 10))

# %%
print(filme1.mean(), filme2.mean())
print(np.std(filme1), np.std(filme2))
print(np.median(filme1), np.median(filme2))
# Out:
# 3.0 3.0
# 0.5 2.0
# 3.0 3.0

# %%
sns.distplot(filme1)
sns.distplot(filme2)
# Out:
# <ipython-input-11-581cbd9a359d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(filme1)
# <ipython-input-11-581cbd9a359d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(filme2)
# <Axes: ylabel='Density'>

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(filme1)
sns.boxplot(filme2)
# Out:
# <Axes: >

# %%
plt.boxplot([filme1, filme2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x784024193a60>,
#   <matplotlib.lines.Line2D at 0x784024193be0>,
#   <matplotlib.lines.Line2D at 0x7840241ccc10>,
#   <matplotlib.lines.Line2D at 0x7840241cceb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x784024193e80>,
#   <matplotlib.lines.Line2D at 0x7840241cc190>,
#   <matplotlib.lines.Line2D at 0x7840241cd150>,
#   <matplotlib.lines.Line2D at 0x7840241cd3f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7840241937c0>,
#   <matplotlib.lines.Line2D at 0x7840241cc970>],
#  'medians': [<matplotlib.lines.Line2D at 0x7840241cc430>,
#   <matplotlib.lines.Line2D at 0x7840241cd690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7840241cc6d0>,
#   <matplotlib.lines.Line2D at 0x7840241cd930>],
#  'means': []}

# %%
sns.boxplot(x=notas_do_toy_story.nota)
sns.boxplot(x=notas_do_jumanji.nota)
# Out:
# <Axes: xlabel='nota'>

# %%
plt.boxplot([notas_do_toy_story.nota, notas_do_jumanji.nota])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x784023da6050>,
#   <matplotlib.lines.Line2D at 0x784023da62f0>,
#   <matplotlib.lines.Line2D at 0x784023da72b0>,
#   <matplotlib.lines.Line2D at 0x784023da7550>],
#  'caps': [<matplotlib.lines.Line2D at 0x784023da6590>,
#   <matplotlib.lines.Line2D at 0x784023da6830>,
#   <matplotlib.lines.Line2D at 0x784023da77f0>,
#   <matplotlib.lines.Line2D at 0x784023da7a90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x784023da5db0>,
#   <matplotlib.lines.Line2D at 0x784023da7010>],
#  'medians': [<matplotlib.lines.Line2D at 0x784023da6ad0>,
#   <matplotlib.lines.Line2D at 0x784023da7d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x784023da6d70>,
#   <matplotlib.lines.Line2D at 0x784023da7fd0>],
#  'means': []}

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in [1,2,3,4,5]"))
# Out:
# <Axes: xlabel='filmeId', ylabel='nota'>
